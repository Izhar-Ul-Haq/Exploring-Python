# %%
import numpy as np
import pandas as pd
import sklearn as sk
# Data Vis By Codanics
import seaborn as sns
import matplotlib.pyplot as plt
# import datasets
kashti = sns.load_dataset('titanic')
print(kashti)
print(kashti.info)
print(kashti.isnull().sum())
print(kashti.survived.value_counts().plot(kind = "bar"))
print(sns.countplot(x = "survived", data = kashti))
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# Learning DataVIZ from Codanics

# %%
plt.scatter(data = kashti, x= "age", y = "fare")

# %%
sns.scatterplot(data = kashti, x = "age", y = "fare", hue = "pclass")
# Out:
# <AxesSubplot: xlabel='age', ylabel='fare'>

# %%
plt.scatter(data = kashti, x = "age", y = "fare")
plt.xlabel("Age")
plt.ylabel("Fare")
plt.title("Scatter plot of Fare vs Age with color")
plt.show()

# %%
sns.barplot(data = kashti, x = "age", y = "fare", hue= "pclass")
# Out:
# <AxesSubplot: xlabel='age', ylabel='fare'>

# %%
sns.pairplot(kashti)
# Out:
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
kashti.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
kashti.hist()
# Out:
# array([[<AxesSubplot: title={'center': 'survived'}>,
#         <AxesSubplot: title={'center': 'pclass'}>],
#        [<AxesSubplot: title={'center': 'age'}>,
#         <AxesSubplot: title={'center': 'sibsp'}>],
#        [<AxesSubplot: title={'center': 'parch'}>,
#         <AxesSubplot: title={'center': 'fare'}>]], dtype=object)

# %%
kashti.hist(bins = 10, figsize=(10, 10))
# Out:
# array([[<AxesSubplot: title={'center': 'survived'}>,
#         <AxesSubplot: title={'center': 'pclass'}>],
#        [<AxesSubplot: title={'center': 'age'}>,
#         <AxesSubplot: title={'center': 'sibsp'}>],
#        [<AxesSubplot: title={'center': 'parch'}>,
#         <AxesSubplot: title={'center': 'fare'}>]], dtype=object)

# %%
kashti.hist(bins = 10, figsize=(10, 10), grid = False)
# Out:
# array([[<AxesSubplot: title={'center': 'survived'}>,
#         <AxesSubplot: title={'center': 'pclass'}>],
#        [<AxesSubplot: title={'center': 'age'}>,
#         <AxesSubplot: title={'center': 'sibsp'}>],
#        [<AxesSubplot: title={'center': 'parch'}>,
#         <AxesSubplot: title={'center': 'fare'}>]], dtype=object)

# %%
sns.boxplot(data = kashti, x = "age", y = "fare", hue = "pclass")
# Out:
# <AxesSubplot: xlabel='age', ylabel='fare'>

# %%
sns.boxenplot(data = kashti, x = "age", y = "fare", hue = "pclass")
# Out:
# <AxesSubplot: xlabel='age', ylabel='fare'>

# %%
g = sns.FacetGrid(kashti,hue="survived", col="pclass", margin_titles=True,
palette={1:"seagreen", 0:"gray"}
    )
g = g.map(plt.scatter, "fare", "age", edgecolor="w").add_legend();
